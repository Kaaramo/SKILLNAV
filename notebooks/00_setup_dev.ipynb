# %% [markdown]
# # 00 — Setup Dev
#
# **Owner** : Binôme (Karamo + Bachirou Konaté)
#
# Sanity-checks de l'environnement local : connexions Mongo/Neo4j/ES, Pydantic AI, Claude API, modèles HuggingFace téléchargés.
#
# À exécuter en premier après `make setup`.
#
# ## Checklist
#
# - [ ] `.env` rempli (toutes les clés)
# - [ ] `poetry env info` → Python 3.12
# - [ ] MongoDB Atlas pingable
# - [ ] Neo4j AuraDB connecté
# - [ ] Elasticsearch Cloud connecté
# - [ ] `anthropic` SDK répond (test petit prompt)
# - [ ] `transformers` charge `bert-base-multilingual-cased`
