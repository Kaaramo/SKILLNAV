# %% [markdown]
# # 01 — Data Quality
#
# **Owner** : **Bachirou Konaté**
#
# Mesure complétude, bruit, biais sur la collection MongoDB `extracted_jobs` (PRD §N3).
#
# ## Sorties attendues
#
# - Tableau **complétude** : taux remplissage par champ Pydantic
# - Tableau **bruit** : cosine sim titre/description, doublons SHA-256, outliers
# - Tableau **biais** : langues FR/EN, géo Maroc/International, taille employeurs, sectoriel
# - JSON pré-calculé pour la page dashboard `/quality` (input `05_dashboard_data_prep.ipynb`)
#
# ## Section du rapport L5 alimentée
#
# §3.6 Data Quality Framework + §5 Discussion (limites, biais).
